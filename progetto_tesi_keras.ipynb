# %% [markdown]
# <a href="https://colab.research.google.com/github/MadalinaStefan/OCR_comparison/blob/main/progetto_tesi_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **STANDARD**

# %%
# !pip install keras_ocr
# !pip install pybind11
# !pip3 install fastwer
# Out:
# Requirement already satisfied: keras_ocr in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (0.6.2)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (1.0)
# Requirement already satisfied: fonttools in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (4.47.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (1.3.0.post5)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (4.66.1)
# Requirement already satisfied: validators in /usr/local/lib/python3.10/dist-packages (from keras_ocr) (0.22.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->keras_ocr) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->keras_ocr) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->keras_ocr) (2.31.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (3.9.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras_ocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras_ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras_ocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras_ocr) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras_ocr) (2.8.2)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.10/dist-packages (2.11.1)
# Requirement already satisfied: fastwer in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.10/dist-packages (from fastwer) (2.11.1)

# %%
from google.colab import drive
import os
import keras_ocr
import matplotlib.pyplot as plt
import pandas as pd
import fastwer

drive.mount('/content/drive')
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images_folder = '/content/drive/MyDrive/immagini_nuovo'
csv_folder = '/content/drive/MyDrive/original_text_nuovo'

images = []
labels = []
true_texts = []

for folder_class in os.listdir(images_folder):
  path = csv_folder + '/' + folder_class + '.csv'
  texts = pd.read_csv(path).values

  #for value in df.values:
  #  true_text.append(value[0])

  for file in os.listdir(images_folder + '/' + folder_class):
    if file.lower().endswith(('.png', '.jpg', '.jpeg')):
      images.append(images_folder + '/' + folder_class + '/' + file)
      labels.append(folder_class)
      index = int(file.split('.')[0])
      true_texts.append(texts[index][0])

# %%
import cv2
import numpy as np

# %%
images_path = images
images = [keras_ocr.tools.read(img) for img in images]
images = np.array(images)
true_texts = np.array(true_texts)
# Out:
# <ipython-input-27-15ab73f2a8d5>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images = np.array(images)

# %%
def visualize_images(images, grey=False):
  f, grid_plot = plt.subplots(4, 5, figsize=(10,20))

  if grey:
    grid_plot[0,0].imshow(images[0], cmap='Greys')
    grid_plot[0,1].imshow(images[1], cmap='Greys')
    grid_plot[0,2].imshow(images[2], cmap='Greys')
    grid_plot[0,3].imshow(images[3], cmap='Greys')
    grid_plot[0,4].imshow(images[4], cmap='Greys')
    grid_plot[1,0].imshow(images[5], cmap='Greys')
    grid_plot[1,1].imshow(images[6], cmap='Greys')
    grid_plot[1,2].imshow(images[7], cmap='Greys')
    grid_plot[1,3].imshow(images[8], cmap='Greys')
    grid_plot[1,4].imshow(images[9], cmap='Greys')
    grid_plot[2,0].imshow(images[10], cmap='Greys')
    grid_plot[2,1].imshow(images[11], cmap='Greys')
    grid_plot[2,2].imshow(images[12], cmap='Greys')
    grid_plot[2,3].imshow(images[13], cmap='Greys')
    grid_plot[2,4].imshow(images[14], cmap='Greys')
    grid_plot[3,0].imshow(images[15], cmap='Greys')
    grid_plot[3,1].imshow(images[16], cmap='Greys')
    grid_plot[3,2].imshow(images[17], cmap='Greys')
    grid_plot[3,3].imshow(images[18], cmap='Greys')
    grid_plot[3,4].imshow(images[19], cmap='Greys')
  else:
    grid_plot[0,0].imshow(images[0])
    grid_plot[0,1].imshow(images[1])
    grid_plot[0,2].imshow(images[2])
    grid_plot[0,3].imshow(images[3])
    grid_plot[0,4].imshow(images[4])
    grid_plot[1,0].imshow(images[5])
    grid_plot[1,1].imshow(images[6])
    grid_plot[1,2].imshow(images[7])
    grid_plot[1,3].imshow(images[8])
    grid_plot[1,4].imshow(images[9])
    grid_plot[2,0].imshow(images[10])
    grid_plot[2,1].imshow(images[11])
    grid_plot[2,2].imshow(images[12])
    grid_plot[2,3].imshow(images[13])
    grid_plot[2,4].imshow(images[14])
    grid_plot[3,0].imshow(images[15])
    grid_plot[3,1].imshow(images[16])
    grid_plot[3,2].imshow(images[17])
    grid_plot[3,3].imshow(images[18])
    grid_plot[3,4].imshow(images[19])

# %%
def resize_image(img, scale_percent=25):
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)

  return cv2.resize(img, dim, interpolation = cv2.INTER_CUBIC)

# %%
import cv2
import numpy as np

def image_transform(images, t_type, scale = False):
  transform_images = []
  images_scaled = []

  if scale:
    for img in images:
      images_scaled.append(resize_image(img, 25))
  else:
    images_scaled = images

  for img in images:
    if t_type == 'blur':
      #image = cv2.GaussianBlur(img, (7, 7), 0)
      image = cv2.blur(img, (7, 7))
    elif t_type == 'rotation':
      image = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    else:
      #weights = [0.2989, 0.5870, 0.1140]
      #image = np.dot(img[..., :3], weights)
      image =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      #image= cv2.imread(img, cv2.IMREAD_GRAYSCALE)


    transform_images.append(image)

  return transform_images

t_images = image_transform(images, 'gray') #rotation, blur o gray

#visualize_images(images, False) #true gray, false blur e rotation
#visualize_images(t_images, True) #true gray, false blur e rotation

# %%
#t_images = image_transform(images, 'rotation') #'blur', 'rotation', 'gray'

#visualize_images(t_images) #true stampa grigio, false a colori

# %% [markdown]
# # **KERAS-OCR**

# %%
import tensorflow as tf

assert tf.test.is_gpu_available(), 'No GPU is available.'

# %%
predictions = pipeline.recognize([images[0]])
#predictions
# Out:
# 1/1 [==============================] - 1s 655ms/step
# 1/1 [==============================] - 2s 2s/step

# %%
pred_texts = []

for image in images:
  predictions = pipeline.recognize([image])

  for prediction in predictions:
    tmp = ''

    for text, box in prediction:
        print(f'Testo: {text}')
        if tmp == '':
          tmp = tmp + text
        else:
          tmp = tmp + ' ' + text

    pred_texts.append(tmp)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 31ms/step
# Testo: onen
# Testo: 3300
# Testo: 22h
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 0s 49ms/step
# Testo:
# Testo: 1957
# Testo: 300
# Testo: sl
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# Testo: wilp
# Testo: asro
# Testo: l652
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# Testo: 951121
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# Testo: 136
# Testo: e507mp
# Testo: rus
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 29ms/step
# Testo: upms
# Testo: chummag
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# Testo: se
# Testo: die
# Testo: euth
# Testo: dont
# Testo: cet
# Testo: s
# Testo: htient
# Testo: yoy
# Testo: ti
# Testo: ee
# Testo: zell
# Testo: che
# Testo: cuo
# Testo: ecah
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 26ms/step
# Testo: stomach
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# Testo: pyd
# Testo: opab
# Testo: gyeoupy
# Testo: insw
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 44ms/step
# Testo: acceptancrs
# Testo: wafla
# Testo: povocrca
# Testo: cotss
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 74ms/step
# Testo: one
# Testo: way
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 69ms/step
# Testo: stop
# Testo: taner
# Testo: ston
# Testo: picpettt
# Testo: right
# Testo: turn
# Testo: only
# Testo: maneri
# Testo: 9n2
# Testo: 1540
# Testo: property
# Testo: city
# Testo: of
# Testo: los
# Testo: angeles
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# Testo: right
# Testo: lane
# Testo: must
# Testo: turn
# Testo: right
# Testo: aceues
# Testo: s
# Testo: s
# Testo: s
# Testo: noperny
# Testo: 01s
# Testo: et
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 58ms/step
# Testo: we
# Testo: ise
# Testo: bn
# Testo: ting
# Testo: l
# Testo: i
# Testo: f
# Testo: s
# Testo: r
# Testo: t
# Testo: he
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# Testo: ga
# Testo: a
# 1/1 [==============================] - 0s 77ms/step
# 16/16 [==============================] - 1s 70ms/step
# Testo: chapter
# Testo: z
# Testo: l
# Testo: found
# Testo: the
# Testo: following
# Testo: return
# Testo: letter
# Testo: nmy
# Testo: from
# Testo: my
# Testo: father
# Testo: victor
# Testo: dear
# Testo: my
# Testo: probably
# Testo: waited
# Testo: impatiently
# Testo: have
# Testo: for
# Testo: you
# Testo: letter
# Testo: a
# Testo: fix
# Testo: to
# Testo: the
# Testo: date
# Testo: of
# Testo: first
# Testo: and
# Testo: l
# Testo: tempted
# Testo: was
# Testo: at
# Testo: write
# Testo: to
# Testo: only
# Testo: few
# Testo: uss
# Testo: lines
# Testo: to
# Testo: a
# Testo: return
# Testo: merely
# Testo: your
# Testo: should
# Testo: which
# Testo: i
# Testo: day
# Testo: expect
# Testo: but
# Testo: the
# Testo: on
# Testo: that
# Testo: you
# Testo: would
# Testo: be
# Testo: mentioning
# Testo: cruel
# Testo: 1
# Testo: do
# Testo: what
# Testo: would
# Testo: it
# Testo: be
# Testo: dare
# Testo: not
# Testo: and
# Testo: i
# Testo: surprise
# Testo: your
# Testo: when
# Testo: my
# Testo: son
# Testo: kindness
# Testo: you
# Testo: glad
# Testo: welcome
# Testo: and
# Testo: behold
# Testo: the
# Testo: to
# Testo: happy
# Testo: on
# Testo: contrary
# Testo: and
# Testo: expected
# Testo: a
# Testo: tears
# Testo: victor
# Testo: l
# Testo: relate
# Testo: misfortunet
# Testo: how
# Testo: and
# Testo: can
# Testo: absence
# Testo: wretchednesst
# Testo: our
# Testo: have
# Testo: cannot
# Testo: and
# Testo: griefs
# Testo: and
# Testo: how
# Testo: joys
# Testo: shall
# Testo: inflict
# Testo: callous
# Testo: our
# Testo: to
# Testo: pain
# Testo: long
# Testo: rendered
# Testo: you
# Testo: on
# Testo: my
# Testo: for
# Testo: woeful
# Testo: the
# Testo: but
# Testo: wish
# Testo: i
# Testo: prepare
# Testo: you
# Testo: know
# Testo: news
# Testo: it
# Testo: is
# Testo: i
# Testo: to
# Testo: impossible
# Testo: sont
# Testo: absent
# Testo: the
# Testo: seek
# Testo: the
# Testo: skims
# Testo: words
# Testo: which
# Testo: over
# Testo: page
# Testo: to
# Testo: eye
# Testo: are
# Testo: to
# Testo: convey
# Testo: your
# Testo: to
# Testo: you
# Testo: now
# Testo: even
# Testo: tidings
# Testo: horrible
# Testo: the
# Testo: child
# Testo: whose
# Testo: deadle
# Testo: that
# Testo: smiles
# Testo: delighted
# Testo: and
# Testo: sweet
# Testo: is
# Testo: warmed
# Testo: william
# Testo: my
# Testo: victor
# Testo: he
# Testo: murdered
# Testo: gentle
# Testo: is
# Testo: gay
# Testo: yet
# Testo: so
# Testo: who
# Testo: was
# Testo: so
# Testo: heart
# Testo: console
# Testo: but
# Testo: will
# Testo: simply
# Testo: relate
# Testo: the
# Testo: circumstances
# Testo: of
# Testo: yous
# Testo: the
# Testo: attempt
# Testo: to
# Testo: will
# Testo: l
# Testo: not
# Testo: transaction
# Testo: and
# Testo: 7thh
# Testo: l
# Testo: niece
# Testo: brothers
# Testo: may
# Testo: walk
# Testo: thursday
# Testo: in
# Testo: my
# Testo: your
# Testo: two
# Testo: went
# Testo: to
# Testo: last
# Testo: and
# Testo: and
# Testo: prolonged
# Testo: farther
# Testo: evening
# Testo: walk
# Testo: the
# Testo: serene
# Testo: plainpalais
# Testo: was
# Testo: warm
# Testo: we
# Testo: our
# Testo: dusk
# Testo: before
# Testo: thought
# Testo: of
# Testo: already
# Testo: and
# Testo: returning
# Testo: then
# Testo: usual
# Testo: lt
# Testo: we
# Testo: was
# Testo: we
# Testo: than
# Testo: before
# Testo: who
# Testo: had
# Testo: william
# Testo: and
# Testo: ernest
# Testo: be
# Testo: found
# Testo: that
# Testo: discovered
# Testo: gone
# Testo: on
# Testo: were
# Testo: not
# Testo: to
# Testo: should
# Testo: until
# Testo: they
# Testo: presently
# Testo: ernest
# Testo: rested
# Testo: and
# Testo: accordingly
# Testo: return
# Testo: seat
# Testo: came
# Testo: we
# Testo: on
# Testo: a
# Testo: said
# Testo: he
# Testo: had
# Testo: been
# Testo: his
# Testo: brother
# Testo: he
# Testo: that
# Testo: playing
# Testo: with
# Testo: him
# Testo: that
# Testo: if
# Testo: had
# Testo: enquired
# Testo: seen
# Testo: we
# Testo: himself
# Testo: and
# Testo: that
# Testo: he
# Testo: for
# Testo: him
# Testo: and
# Testo: hide
# Testo: vainly
# Testo: sought
# Testo: had
# Testo: william
# Testo: to
# Testo: run
# Testo: away
# Testo: he
# Testo: did
# Testo: waited
# Testo: for
# Testo: long
# Testo: but
# Testo: that
# Testo: aferwards
# Testo: time
# Testo: not
# Testo: return
# Testo: a
# Testo: for
# Testo: him
# Testo: until
# Testo: alarmed
# Testo: and
# Testo: continued
# Testo: search
# Testo: night
# Testo: this
# Testo: rather
# Testo: to
# Testo: we
# Testo: account
# Testo: us
# Testo: returned
# Testo: the
# Testo: house
# Testo: he
# Testo: conjectured
# Testo: that
# Testo: he
# Testo: might
# Testo: have
# Testo: fell
# Testo: when
# Testo: elizabeth
# Testo: to
# Testo: was
# Testo: thought
# Testo: that
# Testo: for
# Testo: i
# Testo: could
# Testo: when
# Testo: l
# Testo: with
# Testo: torchess
# Testo: there
# Testo: we
# Testo: returned
# Testo: again
# Testo: not
# Testo: rest
# Testo: not
# Testo: of
# Testo: dews
# Testo: night
# Testo: himself
# Testo: exposed
# Testo: all
# Testo: the
# Testo: damps
# Testo: and
# Testo: boy
# Testo: had
# Testo: lost
# Testo: and
# Testo: to
# Testo: my
# Testo: sweet
# Testo: was
# Testo: discovered
# Testo: l
# Testo: elizabeth
# Testo: about
# Testo: five
# Testo: in
# Testo: the
# Testo: morning
# Testo: also
# Testo: suffered
# Testo: anguish
# Testo: my
# Testo: extreme
# Testo: health
# Testo: lovely
# Testo: and
# Testo: active
# Testo: in
# Testo: before
# Testo: had
# Testo: blooming
# Testo: boy
# Testo: whom
# Testo: night
# Testo: l
# Testo: the
# Testo: scen
# Testo: of
# Testo: murder
# Testo: finger
# Testo: the
# Testo: stretched
# Testo: was
# Testo: on
# Testo: the
# Testo: livid
# Testo: and
# Testo: motionless
# Testo: the
# Testo: print
# Testo: s
# Testo: on
# Testo: grass
# Testo: his
# Testo: neck
# Testo: visible
# Testo: he
# Testo: in
# Testo: countenance
# Testo: anguish
# Testo: that
# Testo: conveyed
# Testo: home
# Testo: and
# Testo: the
# Testo: my
# Testo: was
# Testo: was
# Testo: first
# Testo: l
# Testo: betrayed
# Testo: at
# Testo: the
# Testo: the
# Testo: corpse
# Testo: elizabeth
# Testo: she
# Testo: see
# Testo: carnest
# Testo: to
# Testo: secret
# Testo: to
# Testo: was
# Testo: very
# Testo: where
# Testo: lay
# Testo: it
# Testo: attempted
# Testo: the
# Testo: and
# Testo: entering
# Testo: her
# Testo: persisted
# Testo: room
# Testo: but
# Testo: she
# Testo: to
# Testo: prevent
# Testo: hastily
# Testo: o
# Testo: god
# Testo: exclaimed
# Testo: hands
# Testo: her
# Testo: examined
# Testo: the
# Testo: of
# Testo: and
# Testo: clasping
# Testo: neck
# Testo: the
# Testo: victim
# Testo: ihave
# Testo: murdered
# Testo: darling
# Testo: childr
# Testo: my
# Testo: she
# Testo: lived
# Testo: it
# Testo: again
# Testo: she
# Testo: fainted
# Testo: when
# Testo: difficuly
# Testo: and
# Testo: with
# Testo: restored
# Testo: extreme
# Testo: was
# Testo: 43
# 1/1 [==============================] - 0s 200ms/step
# 5/5 [==============================] - 0s 63ms/step
# Testo: a
# Testo: tis
# Testo: with
# Testo: considerable
# Testo: difficulty
# Testo: of
# Testo: cra
# Testo: being
# Testo: my
# Testo: that
# Testo: all
# Testo: l
# Testo: the
# Testo: remember
# Testo: events
# Testo: of
# Testo: the
# Testo: that
# Testo: original
# Testo: strange
# Testo: period
# Testo: multiplicity
# Testo: appear
# Testo: confused
# Testo: of
# Testo: and
# Testo: smelt
# Testo: sensations
# Testo: indistinct
# Testo: the
# Testo: at
# Testo: seized
# Testo: same
# Testo: time
# Testo: me
# Testo: and
# Testo: and
# Testo: l
# Testo: it
# Testo: felt
# Testo: saw
# Testo: heard
# Testo: was
# Testo: indeed
# Testo: and
# Testo: long
# Testo: a
# Testo: the
# Testo: time
# Testo: ween
# Testo: before
# Testo: l
# Testo: learned
# Testo: operations
# Testo: of
# Testo: distinguish
# Testo: to
# Testo: my
# Testo: various
# Testo: senses
# Testo: by
# Testo: degrees
# Testo: l
# Testo: dressed
# Testo: remember
# Testo: upon
# Testo: a
# Testo: my
# Testo: stronger
# Testo: nerves
# Testo: that
# Testo: l
# Testo: so
# Testo: obliged
# Testo: was
# Testo: shut
# Testo: to
# Testo: my
# Testo: darkness
# Testo: eyes
# Testo: then
# Testo: and
# Testo: vcr
# Testo: troubled
# Testo: me
# Testo: but
# Testo: hardly
# Testo: me
# Testo: had
# Testo: t
# Testo: felt
# Testo: this
# Testo: when
# Testo: by
# Testo: opening
# Testo: my
# Testo: eyes
# Testo: the
# Testo: light
# Testo: suppose
# Testo: poured
# Testo: in
# Testo: again
# Testo: t
# Testo: upon
# Testo: walked
# Testo: me
# Testo: and
# Testo: l
# Testo: believe
# Testo: but
# Testo: l
# Testo: found
# Testo: presently
# Testo: alteration
# Testo: in
# Testo: a
# Testo: great
# Testo: before
# Testo: sensations
# Testo: dark
# Testo: my
# Testo: had
# Testo: surrounded
# Testo: odies
# Testo: touch
# Testo: sight
# Testo: but
# Testo: impervious
# Testo: l
# Testo: me
# Testo: to
# Testo: my
# Testo: or
# Testo: now
# 1/1 [==============================] - 0s 71ms/step
# 3/3 [==============================] - 0s 62ms/step
# Testo: universita
# Testo: pagopp
# Testo: di
# Testo: verona
# Testo: nonn
# Testo: quietanza
# Testo: pagamento
# Testo: di
# Testo: in
# Testo: data
# Testo: 2110512023
# Testo: 1449132
# Testo: universita
# Testo: di
# Testo: verona
# Testo: ha
# Testo: ricevuto
# Testo: la
# Testo: notifica
# Testo: dellavvenuto
# Testo: pagamento
# Testo: conto
# Testo: dii
# Testo: per
# Testo: stefan
# Testo: madalina
# Testo: codice
# Testo: fiscale
# Testo: stfmlnoopa6z
# Testo: 1290
# Testo: dellimporto
# Testo: di
# Testo: e
# Testo: 6261
# Testo: 00
# Testo: causaler
# Testo: con
# Testo: tasse
# Testo: contributi
# Testo: universitari
# Testo: e
# Testo: o010000000
# Testo: 1694970
# Testo: relativo
# Testo: allavviso
# Testo: di
# Testo: pagamento
# Testo: o0000004
# Testo: 1694970
# Testo: iuv
# Testo: con
# Testo: pspi
# Testo: pagamento
# Testo: e
# Testo: stato
# Testo: effettuato
# Testo: tramite
# Testo: pagopa
# Testo: dal
# Testo: il
# Testo: bnlitrr
# Testo: b
# Testo: services
# Testo: worldline
# Testo: merchant
# Testo: italia
# Testo: spa
# Testo: identificato
# Testo: dallindicatore
# Testo: 231410072425
# Testo: stefan
# Testo: pagamentos
# Testo: univoco
# Testo: iur
# Testo: e
# Testo: stato
# Testo: effettuato
# Testo: da
# Testo: il
# Testo: madalina
# Testo: in
# Testo: 2110512023
# Testo: data
# 1/1 [==============================] - 0s 75ms/step
# 3/3 [==============================] - 0s 61ms/step
# Testo: lq
# Testo: diop
# Testo: mo
# Testo: forneria
# Testo: farina
# Testo: pane
# Testo: e
# Testo: s
# Testo: io
# Testo: lot
# Testo: di
# Testo: capuzzi
# Testo: sandro
# Testo: a
# Testo: c
# Testo: sas
# Testo: viale
# Testo: europa
# Testo: 22
# Testo: 25
# Testo: 108
# Testo: montichiari
# Testo: bs
# Testo: lul
# Testo: sv
# Testo: na
# Testo: ival
# Testo: ps
# Testo: 0249640987
# Testo: nay
# Testo: tele
# Testo: 0309962587
# Testo: documento
# Testo: commerciale
# Testo: vendita
# Testo: di
# Testo: prestaz
# Testo: ione
# Testo: o
# Testo: descrizione
# Testo: iva
# Testo: prezzofey
# Testo: pane
# Testo: 45
# Testo: oo0
# Testo: 65
# Testo: 13
# Testo: d
# Testo: totale
# Testo: complession
# Testo: 3
# Testo: 65
# Testo: aal
# Testo: di
# Testo: cui
# Testo: tva
# Testo: 52
# Testo: on
# Testo: pagamento
# Testo: elettronico
# Testo: 135
# Testo: 65
# Testo: importo
# Testo: pagato
# Testo: col
# Testo: bia
# Testo: 184
# Testo: 65
# Testo: 13012024
# Testo: 09127
# Testo: laml
# Testo: documento
# Testo: n
# Testo: 088410191
# Testo: am
# Testo: ri
# Testo: ggieb020508
# Testo: dettagl
# Testo: io
# Testo: forme
# Testo: di
# Testo: pagamento
# Testo: pago
# Testo: bancomat
# Testo: 65
# Testo: 135
# Testo: nome
# Testo: post
# Testo: panefarina
# Testo: fa
# Testo: rifer
# Testo: banco
# Testo: opere
# Testo: manager
# Testo: droddey
# Testo: 8od
# 1/1 [==============================] - 0s 54ms/step
# 4/4 [==============================] - 0s 52ms/step
# Testo: transaz
# Testo:
# Testo: i
# Testo: esegui
# Testo: ta
# Testo: one
# Testo: ail
# Testo: grazie
# Testo: arri
# Testo: vederci
# Testo: e
# Testo: banco
# Testo: bpm
# Testo: s
# Testo: d
# Testo: bpm
# Testo:
# Testo: banco
# Testo: nexi
# Testo: maestro
# Testo: s
# Testo: acquisto
# Testo: s
# Testo: farina
# Testo: pane
# Testo: e
# Testo: forneria
# Testo: montichiari
# Testo: s
# Testo: 7364619
# Testo: eser
# Testo: 8oggbbo603
# Testo: iic
# Testo: a
# Testo: s
# Testo: 899
# Testo: 27
# Testo: 13101124
# Testo: ora
# Testo: data
# Testo: 229853
# Testo: 02412712
# Testo: stan
# Testo: tml
# Testo: 6
# Testo: ctls
# Testo: icc
# Testo: online
# Testo: mod
# Testo: pani
# Testo: rssn
# Testo: expi
# Testo: fxs
# Testo: aut
# Testo: 883549
# Testo: 028101
# Testo: opere
# Testo: arc
# Testo: 80
# Testo: maes
# Testo: tno
# Testo: tac
# Testo: tless
# Testo: cont
# Testo: ndooabion
# Testo: id
# Testo: a
# Testo: appl
# Testo: maestiao
# Testo: o
# Testo: atc
# Testo: bo6
# Testo: tc
# Testo: j60
# Testo: tt
# Testo: os
# Testo: trc
# Testo: 916
# Testo: un
# Testo: eosfcgeo
# Testo: tva
# Testo: bosbbo
# Testo: ar
# Testo: o
# Testo: c
# Testo: ebef
# Testo: bbegcretccf
# Testo: s
# Testo: iad
# Testo: an
# Testo: no
# Testo: cym
# Testo: importo
# Testo: e
# Testo: 1
# Testo: 65
# Testo: transazi
# Testo: one
# Testo: esegui
# Testo: ta
# Testo: aut
# Testo: nabe8540
# Testo: grazie
# Testo: anri
# Testo: vederci
# Testo: e
# Testo: banco
# Testo: bpm

# %%
print(pred_texts)
# Out:
# ['onen 3300 22h', '1957 300 sl', 'wilp asro l652', '951121', '136 e507mp rus', 'upms chummag', 'se die euth dont cet s htient yoy ti ee zell che cuo ecah', 'stomach', 'pyd opab gyeoupy insw', 'acceptancrs wafla povocrca cotss', 'one way', 'stop taner ston picpettt right turn only maneri 9n2 1540 property city of los angeles', 'right lane must turn right aceues s s s noperny 01s et', 'we ise bn ting l i f s r t he', 'ga a', 'chapter z l found the following return letter nmy from my father victor dear my probably waited impatiently have for you letter a fix to the date of first and l tempted was at write to only few uss lines to a return merely your should which i day expect but the on that you would be mentioning cruel 1 do what would it be dare not and i surprise your when my son kindness you glad welcome and behold the to happy on contrary and expected a tears victor l relate misfortunet how and can absence wretchednesst our have cannot and griefs and how joys shall inflict callous our to pain long rendered you on my for woeful the but wish i prepare you know news it is i to impossible sont absent the seek the skims words which over page to eye are to convey your to you now even tidings horrible the child whose deadle that smiles delighted and sweet is warmed william my victor he murdered gentle is gay yet so who was so heart console but will simply relate the circumstances of yous the attempt to will l not transaction and 7thh l niece brothers may walk thursday in my your two went to last and and prolonged farther evening walk the serene plainpalais was warm we our dusk before thought of already and returning then usual lt we was we than before who had william and ernest be found that discovered gone on were not to should until they presently ernest rested and accordingly return seat came we on a said he had been his brother he that playing with him that if had enquired seen we himself and that he for him and hide vainly sought had william to run away he did waited for long but that aferwards time not return a for him until alarmed and continued search night this rather to we account us returned the house he conjectured that he might have fell when elizabeth to was thought that for i could when l with torchess there we returned again not rest not of dews night himself exposed all the damps and boy had lost and to my sweet was discovered l elizabeth about five in the morning also suffered anguish my extreme health lovely and active in before had blooming boy whom night l the scen of murder finger the stretched was on the livid and motionless the print s on grass his neck visible he in countenance anguish that conveyed home and the my was was first l betrayed at the the corpse elizabeth she see carnest to secret to was very where lay it attempted the and entering her persisted room but she to prevent hastily o god exclaimed hands her examined the of and clasping neck the victim ihave murdered darling childr my she lived it again she fainted when difficuly and with restored extreme was 43', 'a tis with considerable difficulty of cra being my that all l the remember events of the that original strange period multiplicity appear confused of and smelt sensations indistinct the at seized same time me and and l it felt saw heard was indeed and long a the time ween before l learned operations of distinguish to my various senses by degrees l dressed remember upon a my stronger nerves that l so obliged was shut to my darkness eyes then and vcr troubled me but hardly me had t felt this when by opening my eyes the light suppose poured in again t upon walked me and l believe but l found presently alteration in a great before sensations dark my had surrounded odies touch sight but impervious l me to my or now', 'universita pagopp di verona nonn quietanza pagamento di in data 2110512023 1449132 universita di verona ha ricevuto la notifica dellavvenuto pagamento conto dii per stefan madalina codice fiscale stfmlnoopa6z 1290 dellimporto di e  ...

# %% [markdown]
# # **METRICHE - STANDARD**

# %%
#Sentence-Level Character Error Rate (CER)
for i in range(len(pred_texts)):
  print(fastwer.score_sent(pred_texts[i].lower(), true_texts[i].lower(), char_level=True))
# Out:
# 88.8889
# 90.9091
# 100.0
# 60.0
# 58.3333
# 66.6667
# 191.3043
# 0.0
# 121.4286
# 50.0
# 0.0
# 325.0
# 107.6923
# 65.3846
# 80.0
# 416.7266
# 122.1739
# 36.8687
# 75.8713
# 86.167

# %%
#Sentence-Level Word Error Rate (WER)
for i in range(len(pred_texts)):
  print(fastwer.score_sent(pred_texts[i].lower(), true_texts[i].lower()))
# Out:
# 100.0
# 66.6667
# 150.0
# 100.0
# 300.0
# 100.0
# 280.0
# 0.0
# 133.3333
# 100.0
# 0.0
# 275.0
# 140.0
# 200.0
# 200.0
# 664.8649
# 210.9375
# 68.4932
# 99.2647
# 99.1853

# %%
from PIL import Image

# %%
from re import L

def ocr_on_folder(images):
    pipeline = keras_ocr.pipeline.Pipeline()

    pred_texts = []

    for image_path in images:
        image = keras_ocr.tools.read(image_path)
        prediction_groups = pipeline.recognize([image])
        text = ' '.join([word_info[0] for word_info in prediction_groups[0]])
        pred_texts.append(text)

    return pred_texts

# %%
def calculate_scores(pred_texts, true_texts):
  scores_cer = [ fastwer.score_sent(pred_texts[i].lower(), true_texts[i].lower(), char_level=True) for i in range(len(pred_texts)) ]

  scores_wer = [ fastwer.score_sent(pred_texts[i].lower(), true_texts[i].lower()) for i in range(len(pred_texts)) ]

  return scores_cer, scores_wer

# %%
def generate_csv(data_class, trans, cer, wer):
  d = {'augmentation': trans, 'cer': cer, 'wer': wer}
  df = pd.DataFrame(data=d)

  csv_name = data_class + '.csv'
  df.to_csv(csv_name, sep=',', index=False)
  df

# %%
labels = np.array(labels)
quality = ['high', 'low']
augmentation = ['natural', 'blur', 'rotation'] #gray

for label in set(labels):
  print(label)
  class_index = np.where(labels==label)[0]
  test_images = []

  column_cer = []
  column_wer = []
  column_trans = []

  for q in quality:
    for a in augmentation:
      print(q+'-'+a)
      if a == 'natural' and q == 'low':
        test_images = [resize_image(x) for x in images[class_index]]
      elif a == 'natural' and q == 'high':
        test_images = images[class_index]

      if a != 'natural':
        if q == 'high':
          test_images = image_transform(images[class_index], a)
        else:
          test_images = image_transform(images[class_index], a, scale=True)

      pred_texts = ocr_on_folder(test_images)

      cer, wer = calculate_scores(pred_texts, true_texts[class_index])

      column_cer.append(round(np.mean(cer), 2))
      column_wer.append(round(np.mean(wer), 2))
      column_trans.append(str(q)+'-'+str(a))

  generate_csv(label, column_trans, column_cer, column_wer)
# Out:
# handwritten_texts
# high-natural
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 43ms/step
# high-blur
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - ETA: 0s
